# %%
import numpy as np
#from sympy import *
from matplotlib import pyplot as plt
from scipy import signal
import control

# %% [markdown]
# # Trabajo practico N°1

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# i) $$\begin{equation} \frac{Y(s)}{X(s)} = \frac{125}{s^2+10s+25}\end{equation}$$

# %% [markdown]
# #### Transferencia

# %% [markdown]
# $$\begin{equation} H(s) = \frac{125}{(s+5)^2}\end{equation}$$

# %% [markdown]
# #### Ecuacion diferencial

# %% [markdown]
# $$\begin{equation} \frac{d^2y(t)}{dt^2} + 10\frac{dy(t)}{dt} + 25y(t) = 125x(t)\end{equation}$$

# %% [markdown]
# #### Polos y ceros

# %%
num1 = np.array([0, 0, 125])
den1 = np.array([1, 10, 25])

tf1 = control.tf(num1, den1)
control.pzmap(tf1);

# %% [markdown]
# #### Respuesta al escalon

# %%
t, y = control.step_response(tf1)
#plt.plot(t, y, label= "time");
fig, ax = plt.subplots()
ax.plot(t, y)

ax.set(xlabel='time [s]', ylabel='amplitud []', title='Step Response');

# %% [markdown]
# ##### Analiticamente llegue a la siguiente expresion

# %% [markdown]
# $$\begin{equation}y(t) = 5[1-e^{-5t}(1+5t)]u(t)\end{equation}$$

# %% [markdown]
# ##### Vamos a graficarla

# %%
u = np.ones(t.size)
y = 5 * (1 - np.exp(-5 * t) * (1 + 5 * t)) * u

fig, ax = plt.subplots()
ax.plot(t, y)
ax.set(xlabel='time [s]', ylabel='amplitud []', title='Step Response');

# %% [markdown]
# ii) $$\begin{equation} \frac{Y(s)}{X(s)} = \frac{10}{s^2+2s+5}\end{equation}$$

# %% [markdown]
# #### Transferencia

# %% [markdown]
# $$\begin{equation} H(s) = \frac{10}{s^2+2s+5}\end{equation}$$

# %% [markdown]
# #### Ecuacion diferencial

# %% [markdown]
# $$\begin{equation} \frac{d^2y(t)}{dt^2} + 2\frac{dy(t)}{dt} + 5y(t) = 10x(t)\end{equation}$$

# %% [markdown]
# #### Polos y ceros

# %%
num = np.array([0, 0, 10])
den = np.array([1, 2, 5])

tf = control.tf(num, den)
control.pzmap(tf);

# %% [markdown]
# #### Respuesta al escalon

# %%
t, y = control.step_response(tf)
#plt.plot(t, y, label= "time");
fig, ax = plt.subplots()
ax.plot(t, y)

ax.set(xlabel='time [s]', ylabel='amplitud []', title='Step Response');

# %% [markdown]
# ##### Analiticamente llegue a la siguiente expresion

# %% [markdown]
# $$\begin{equation}y(t) = 2[1-(cos(2t)+\frac{1}{2}sin(2t)) e^{-t}]u(t)\end{equation}$$

# %% [markdown]
# ##### Vamos a graficarla

# %%
u = np.ones(t.size)
y = 2 * (1 - (np.cos(2*t)+0.5*np.sin(2*t))*np.exp(-t))*u

fig, ax = plt.subplots()
ax.plot(t, y)
ax.set(xlabel='time [s]', ylabel='amplitud []', title='Step Response');

# %% [markdown]
# vi)$$\begin{equation} y(t) = 8x(t) + 6\int_0^t x(\tau)d\tau + 2 \frac{dx(t)}{dt}\end{equation}$$

# %% [markdown]
# #### Transferencia

# %% [markdown]
# $$\begin{equation} H(s) = 2\frac{s^2+4s+3}{s}=2\frac{(s+1)(s+3)}{s}\end{equation}$$

# %%
#Que onda con esta? Esta mal?

# %% [markdown]
# #### Ecuacion diferencial

# %% [markdown]
# $$\begin{equation} \frac{dy(t)}{dt} = 2\frac{d^2x(t)}{dt^2} + 8\frac{dx(t)}{dt} + 6x(t)\end{equation}$$

# %% [markdown]
# #### Polos y ceros

# %%
num = 2*np.array([1, 4, 3])
den = np.array([0, 1, 0])

tf = control.tf(num, den)
control.pzmap(tf);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-707fec49f678> in <module>
#       3
#       4 tf = control.tf(num, den)
# ----> 5 control.pzmap(tf);
#
# ~/anaconda3/lib/python3.7/site-packages/control/pzmap.py in pzmap(sys, Plot, grid, title)
#      75         raise TypeError('Argument ``sys``: must be a linear system.')
#      76
# ---> 77     poles = sys.pole()
#      78     zeros = sys.zero()
#      79
#
# ~/anaconda3/lib/python3.7/site-packages/control/xferfcn.py in pole(self)
#     651     def pole(self):
#     652         """Compute the poles of a transfer function."""
# --> 653         num, den, denorder = self._common_den()
#     654         rts = []
#     655         for d, o in zip(den, denorder):
#
# ~/anaconda3/lib/python3.7/site-packages/control/xferfcn.py in _common_den(self, imag_tol)
#     894                     # numerator polynomial should be padded on left and right
#     895                     #   ending at np to line up with what td04ad expects...
# --> 896                     num[i, j, np + 1 - len(numpoly):np + 1] = numpoly[::-1]
#     897                     # print(num[i, j])
#     898
#
# ValueError: could not broadcast input array from shape (3) into shape (1)

# %% [markdown]
# #### Respuesta al escalon

# %%
t, y = control.step_response(tf)
#plt.plot(t, y, label= "time");
fig, ax = plt.subplots()
ax.plot(t, y)

ax.set(xlabel='time [s]', ylabel='amplitud []', title='Step Response');

# %% [markdown]
# ##### Analiticamente llegue a la siguiente expresion

# %% [markdown]
# $$\begin{equation}y(t) = 2\delta(t) + (8 + 6t)u(t)\end{equation}$$

# %% [markdown]
# ##### Vamos a graficarla

# %%
u = np.ones(t.size)
d = np.inf + np.zeros(t.size -1)

y = 2*d + (8+6*t)u

fig, ax = plt.subplots()
ax.plot(t, y)
ax.set(xlabel='time [s]', ylabel='amplitud []', title='Step Response');

# %% [markdown]
# ix)

# %% [markdown]
# #### Transferencia

# %% [markdown]
# $$\begin{equation} H(s) = \frac{60}{(s+1)(s+2)(s+3)}=\frac{60}{s^3+6s^2+11s+6}\end{equation}$$

# %% [markdown]
# #### Ecuacion diferencial

# %% [markdown]
# $$\begin{equation} \frac{d^3y(t)}{dt^3} + 6\frac{d^2y(t)}{dt^2} + 11\frac{dy(t)}{dt} + 6y(t) = 60x(t) \end{equation}$$

# %% [markdown]
# #### Polos y ceros

# %%
num = np.array([0, 0, 0, 60])
den = np.array([1, 6, 11, 6])

tf = control.tf(num, den)
control.pzmap(tf);

# %% [markdown]
# #### Respuesta al escalon

# %%
t, y = control.step_response(tf)
#plt.plot(t, y, label= "time");
fig, ax = plt.subplots()
ax.plot(t, y)

ax.set(xlabel='time [s]', ylabel='amplitud []', title='Step Response');

# %% [markdown]
# ##### Analiticamente llegue a la siguiente expresion

# %% [markdown]
# $$\begin{equation}y(t) = 10[1-3e^{-t}+3e^{-2t}-e^{-3t}]u(t)\end{equation}$$

# %% [markdown]
# ##### Vamos a graficarla

# %%
u = np.ones(t.size)

y = 10 * (1 - 3*np.exp(-t) + 3*np.exp(-2*t) - np.exp(-3*t)) * u

fig, ax = plt.subplots()
ax.plot(t, y)
ax.set(xlabel='time [s]', ylabel='amplitud []', title='Step Response');

# %% [markdown]
# xii)

# %% [markdown]
# #### Transferencia

# %% [markdown]
# $$\begin{equation} H(s) = -3\frac{s-6}{s^2+6s+18}\end{equation}$$

# %% [markdown]
# #### Ecuacion diferencial

# %% [markdown]
# $$\begin{equation} \frac{d^2y(t)}{dt^2} + 6\frac{dy(t)}{dt} + 8y(t) = -3\frac{dx(t)}{dt} + 18x(t)\end{equation}$$

# %% [markdown]
# #### Polos y ceros

# %%
num = -3 * np.array([0, 1, -6])
den = np.array([1, 6, 18])

tf = control.tf(num, den)
control.pzmap(tf);

# %% [markdown]
# #### Respuesta al escalon

# %%
t, y = control.step_response(tf)
#plt.plot(t, y, label= "time");
fig, ax = plt.subplots()
ax.plot(t, y)

ax.set(xlabel='time [s]', ylabel='amplitud []', title='Step Response');

# %% [markdown]
# ##### Analiticamente llegue a la siguiente expresion

# %% [markdown]
# $$\begin{equation}y(t) = -[(2sen(3t) + cos(3t))e^{-3t} + 1]u(t)\end{equation}$$

# %% [markdown]
# ##### Vamos a graficarla

# %%
u = np.ones(t.size)
y = ( -(2*np.sin(3*t) + np.cos(3*t)) * np.exp(-3*t) + 1 ) * u
fig, ax = plt.subplots()
ax.plot(t, y)
ax.set(xlabel='time [s]', ylabel='amplitud []', title='Step Response');
